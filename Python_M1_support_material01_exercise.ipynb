# %% [markdown]
# <a href="https://colab.research.google.com/github/Guspex/FSP-EBAC/blob/main/Python_M1_support_material01_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Python: Variáveis & Tipos de Dados
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Introdução ao Google Colab;</li>
#   <li>Variáveis;</li>
#   <li>Números;</li>
#   <li><i>Strings;</i></li>
#   <li>Boleanos.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Google Colab

# %% [markdown]
# Crie uma célula de código que escreva o texto "Olá mundo!", utilize o comando `print`.

# %% [markdown]
# Crie uma célua de texto e adicione uma imagem.

# %% [markdown]
# ---

# %% [markdown]
# ![c5fd90ba05d513a2f657b9ae565f5713_XL.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 2\. Números

# %% [markdown]
# Preencha as células de código para preencher os valores de (A), (B) e (C) na tabela de ticket médio abaixo:
#
# <br>
#
# | Dia   | Valor Total Vendas | Qtd Total Vendas | Ticket Medio |
# |-------|--------------------|------------------|--------------|
# | 19/01 | (A)                | 3                | 320.52       |
# | 20/01 | 834.47             | (B)              | 119.21       |
# | 23/01 | 15378.12           | 5                | (C)          |

# %%
# (A)
qtdTotalVendas = 3
ticketMedio = 320.52
valorTotalVendas = ticketMedio * qtdTotalVendas
print(valorTotalVendas)
# Out:
# 961.56

# %%
# (B)
valorTotalVendas = 834.47
ticketMedio = 119.21
qtdTotalVendas = valorTotalVendas / ticketMedio
print(int(qtdTotalVendas))
# Out:
# 7

# %%
# (C)
valorTotalVendas = 15378.12
qtdTotalVendas = 5
ticketMedio = valorTotalVendas / qtdTotalVendas
print(ticketMedio)
# Out:
# 3075.6240000000003

# %% [markdown]
# ---

# %% [markdown]
# ## 3\. Strings

# %% [markdown]
# Aplique três métodos distintos na *string* abaixo, você pode conferir alguns métodos neste [link](https://www.w3schools.com/python/python_ref_string.asp):

# %%
cancao = 'Roda mundo, roda gigante, roda moinho, roda pião.'
mini = cancao.casefold()
print(mini)
cap = mini.capitalize()
print(cap)
maisc = cap.upper()
print(maisc)
# Out:
# roda mundo, roda gigante, roda moinho, roda pião.
# Roda mundo, roda gigante, roda moinho, roda pião.
# RODA MUNDO, RODA GIGANTE, RODA MOINHO, RODA PIÃO.

# %% [markdown]
# Extraia da string abaixo o valor da taxa **selic** na variável `selic` e o valor do **ano** na variavel `ano`. Imprima os valores na tela.

# %%
import re
noticia = 'Selic vai a 2,75% e supera expectativas; é a primeira alta em 6 anos.'
matches = re.findall(r'\d+,\d+|\d+', noticia)
selic = matches[0]
ano = matches[-1]
print("Taxa Selic:", selic)
print("Ano:", ano)
# Out:
# Taxa Selic: 2,75
# Ano: 6

# %% [markdown]
# ---

# %% [markdown]
# ## 4\. Booleanos

# %% [markdown]
# Utilize a tabela da verdade para responder: qual o valor da variável x?

# %%
a = False
b = True

x = not a & b

# %% [markdown]
# X tem valor de **True**
